# %%
from sportsreference.ncaab.teams import Teams

# %%
https://medium.com/clarktech-sports/python-sports-analytics-made-simple-part-2-40e591a7f3db

# %%
#create an empty data frame and each time, append the data into into it
#figure out how to create that code

for team in Teams():
    print(team.name)
    print(team.dataframe)
# Out:
# North Carolina-Greensboro
#                                         abbreviation  assist_percentage  \
# NORTH-CAROLINA-GREENSBORO  NORTH-CAROLINA-GREENSBORO               45.4
#
#                            assists  away_losses  away_wins  block_percentage  \
# NORTH-CAROLINA-GREENSBORO      453            4         11              11.5
#
#                            blocks conference  conference_losses  \
# NORTH-CAROLINA-GREENSBORO     140   southern                  3
#
#                            conference_wins  ...  total_rebound_percentage  \
# NORTH-CAROLINA-GREENSBORO               15  ...                      50.7
#
#                            total_rebounds  true_shooting_percentage  \
# NORTH-CAROLINA-GREENSBORO            1251                     0.548
#
#                            turnover_percentage  turnovers  \
# NORTH-CAROLINA-GREENSBORO                 14.5        423
#
#                            two_point_field_goal_attempts  \
# ...

# %%
df = team.dataframe

# %%
df.tail()
# Out:
#                 abbreviation  assist_percentage  assists  away_losses  \
# SOUTH-FLORIDA  SOUTH-FLORIDA               57.2      521            7
#
#                away_wins  block_percentage  blocks conference  \
# SOUTH-FLORIDA          5               9.7     124        aac
#
#                conference_losses  conference_wins  ...  \
# SOUTH-FLORIDA                 10                8  ...
#
#                total_rebound_percentage  total_rebounds  \
# SOUTH-FLORIDA                      54.7            1483
#
#                true_shooting_percentage  turnover_percentage  turnovers  \
# SOUTH-FLORIDA                     0.529                 18.8        604
#
#                two_point_field_goal_attempts  two_point_field_goal_percentage  \
# SOUTH-FLORIDA                           1301                            0.491
#
#                two_point_field_goals  win_percentage  wins
# SOUTH-FLORIDA                    639           0.632    24
#
# [1 rows x 84 columns]
